# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/home/lankenau/isotools/src')

# %%
import os
import logging
from isotools import Transcriptome
from isotools import __version__ as isotools_version
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# set up logging
logging.basicConfig(format="%(levelname)s:%(message)s", level=logging.INFO)
logger = logging.getLogger("isotools")
logger.info(f"This is isotools version {isotools_version}")
# Out:
# INFO:This is isotools version 0.3.5rc11

# %%
isotools_pkl = 'path/to/notebooks/results/flair_isotools.pkl'
sqanti_classification = 'path/to/snakemake-pipeline/results/sqanti/flair/qc/aorta/aorta_classification.txt'

# %%
sqanti_df = pd.read_csv(sqanti_classification, sep='\t')
# Rename and make boolean
sqanti_df['category'] = sqanti_df['structural_category']
sqanti_df['TSS ratio'] = sqanti_df['ratio_TSS'] > 1.5
sqanti_df['CAGE support'] = sqanti_df['within_CAGE_peak']
sqanti_df['polyA site'] = sqanti_df['within_polyA_site']
sqanti_df['polyA motif'] = sqanti_df['polyA_motif_found']
sqanti_df['start both'] = sqanti_df['TSS ratio'] & sqanti_df['CAGE support']
sqanti_df['end both'] = sqanti_df['polyA site'] & sqanti_df['polyA motif']

sqanti_df['category'] = sqanti_df['category'].replace({
    'intergenic': 'Intergenic',
    'antisense': 'Antisense',
    'genic': 'Genic',
    'genic_intron': 'Genic Intron',
    'fusion': 'Fusion',
    'full-splice_match': 'FSM',
    'incomplete-splice_match': 'ISM',
    'novel_in_catalog': 'NIC',
    'novel_not_in_catalog': 'NNC'
})

# %%
sqanti_df = sqanti_df.loc[:,['isoform', 'category', 'subcategory']]
sqanti_df
# Out:
#                                    isoform      category  \
# 0                       ENST00000037502.11           FSM
# 1                        ENST00000040877.2           FSM
# 2                       ENST00000054666.11           FSM
# 3                        ENST00000060969.6           FSM
# 4                        ENST00000072644.7           FSM
# ...                                    ...           ...
# 109140  m54284U_210227_205004/70453536/ccs           NIC
# 109141    m54284U_210227_205004/722100/ccs    Intergenic
# 109142  m54284U_210227_205004/72286900/ccs  Genic Intron
# 109143  m54284U_210227_205004/83820795/ccs  Genic Intron
# 109144  m54284U_210227_205004/88410435/ccs     Antisense
#
#                              subcategory
# 0                        reference_match
# 1                        reference_match
# 2                        reference_match
# 3                   alternative_3end5end
# 4                        reference_match
# ...                                  ...
# 109140  combination_of_known_splicesites
# 109141                         mono-exon
# 109142                         mono-exon
# 109143                         mono-exon
# 109144                         mono-exon
#
# [109145 rows x 3 columns]

# %%
isoseq = Transcriptome.load(isotools_pkl)

# %%
isotools_df = isoseq.transcript_table(query="", extra_columns=["transcript_id"])\
# check if transcript_id is unique, otherwise
# create isoform column from gene_id + _ + transcript_nr
if len(isotools_df['transcript_id'].unique()) == isotools_df.shape[0]:
    isotools_df = isotools_df.assign(isoform=isotools_df['transcript_id'])
else:
    isotools_df = isotools_df.assign(isoform=isotools_df['gene_id'] + '_' + isotools_df['transcript_nr'].astype(str))
# rename novelty_class to isotools_category and novelty_subclasses to isotools_subcategory
isotools_df = isotools_df.rename(columns={'novelty_class': 'isotools_category', 'novelty_subclasses': 'isotools_subcategory'})
isotools_df = isotools_df.loc[:,['gene_id', 'isoform', 'isotools_category', 'isotools_subcategory', 'chr', 'transcript_start', 'transcript_end']]

# %%
isotools_df
# Out:
#                    gene_id                              isoform  \
# 0       ENSG00000121957.15   m54284U_210227_205004/37357274/ccs
# 1       ENSG00000121957.15   m54284U_210227_205004/61016242/ccs
# 2       ENSG00000121957.15   m54284U_210227_205004/84346647/ccs
# 3       ENSG00000121957.15  m54284U_210227_205004/103220783/ccs
# 4       ENSG00000121957.15                    ENST00000264126.9
# ...                    ...                                  ...
# 107486      IT_novel_53673  m54284U_200419_012632/115279072/ccs
# 107487   ENSG00000292335.1  m54284U_210227_205004/121636612/ccs
# 107488      IT_novel_53657   m54284U_210227_205004/20318378/ccs
# 107489      IT_novel_53664   m54284U_200419_012632/12716168/ccs
# 107490   ENSG00000292342.1  m54284U_200419_012632/106826569/ccs
#
#        isotools_category isotools_subcategory   chr  transcript_start  \
# 0                    ISM            mono-exon  chr1         108876984
# 1                    ISM            mono-exon  chr1         108906669
# 2                    ISM            mono-exon  chr1         108925726
# 3                    ISM            mono-exon  chr1         108928073
# 4                    FSM                  FSM  chr1         108876984
# ...                  ...                  ...   ...               ...
# 107486             NOVEL            antisense  chrY           1385100
# 107487               ISM            mono-exon  chrY            992801
# 107488             NOVEL             intronic  chrY           1405441
# 107489             NOVEL        genic genomic  chrY           1415645
# 107490               ISM            mono-exon  chrY            319175
#
#         transcript_end
# 0            108880418
# 1            108909981
# 2            108926898
# 3            108931970
# 4            108930382
# ...                ...
# 107486         1386656
# 107487          994365
# 107488         1407766
# 107489         1418144
# 107490          321317
#
# [107491 rows x 7 columns]

# %%
# join dfs
df = pd.merge(isotools_df, sqanti_df, on='isoform', how='inner')
df
# Out:
#                    gene_id                              isoform  \
# 0       ENSG00000121957.15   m54284U_210227_205004/37357274/ccs
# 1       ENSG00000121957.15   m54284U_210227_205004/61016242/ccs
# 2       ENSG00000121957.15   m54284U_210227_205004/84346647/ccs
# 3       ENSG00000121957.15  m54284U_210227_205004/103220783/ccs
# 4       ENSG00000121957.15                    ENST00000264126.9
# ...                    ...                                  ...
# 107486      IT_novel_53673  m54284U_200419_012632/115279072/ccs
# 107487   ENSG00000292335.1  m54284U_210227_205004/121636612/ccs
# 107488      IT_novel_53657   m54284U_210227_205004/20318378/ccs
# 107489      IT_novel_53664   m54284U_200419_012632/12716168/ccs
# 107490   ENSG00000292342.1  m54284U_200419_012632/106826569/ccs
#
#        isotools_category isotools_subcategory   chr  transcript_start  \
# 0                    ISM            mono-exon  chr1         108876984
# 1                    ISM            mono-exon  chr1         108906669
# 2                    ISM            mono-exon  chr1         108925726
# 3                    ISM            mono-exon  chr1         108928073
# 4                    FSM                  FSM  chr1         108876984
# ...                  ...                  ...   ...               ...
# 107486             NOVEL            antisense  chrY           1385100
# 107487               ISM            mono-exon  chrY            992801
# 107488             NOVEL             intronic  chrY           1405441
# 107489             NOVEL        genic genomic  chrY           1415645
# 107490               ISM            mono-exon  chrY            319175
#
#         transcript_end      category                    subcategory
# 0            108880418           NIC  mono-exon_by_intron_retention
# 1            108909981         Genic                      mono-exon
# 2            108926898         Genic                      mono-exon
# 3            108931970           NIC  mono-exon_by_intron_retention
# 4            108930382           FSM               alternative_3end
# ...                ...           ...                            ...
# 107486         1386656     Antisense                      mono-exon
# 107487          994365         Genic                      mono-exon
# 107488         1407766  Genic Intron                      mono-exon
# 107489         1418144         Genic                      mono-exon
# 107490          321317         Genic                      mono-exon
#
# [107491 rows x 9 columns]

# %%
mismatches = df.loc[(df['category'] != df['isotools_category']) & (df['isotools_category'] != 'NOVEL')]
mismatches
# Out:
#                    gene_id                              isoform  \
# 0       ENSG00000121957.15   m54284U_210227_205004/37357274/ccs
# 1       ENSG00000121957.15   m54284U_210227_205004/61016242/ccs
# 2       ENSG00000121957.15   m54284U_210227_205004/84346647/ccs
# 3       ENSG00000121957.15  m54284U_210227_205004/103220783/ccs
# 7       ENSG00000163431.14   m54284U_200419_012632/53545803/ccs
# ...                    ...                                  ...
# 107424  ENSG00000157514.18   m54284U_200419_012632/25363560/ccs
# 107444   ENSG00000292341.1  m54284U_210227_205004/123078285/ccs
# 107455   ENSG00000292357.1   m54284U_210227_205004/33751947/ccs
# 107487   ENSG00000292335.1  m54284U_210227_205004/121636612/ccs
# 107490   ENSG00000292342.1  m54284U_200419_012632/106826569/ccs
#
#        isotools_category isotools_subcategory   chr  transcript_start  \
# 0                    ISM            mono-exon  chr1         108876984
# 1                    ISM            mono-exon  chr1         108906669
# 2                    ISM            mono-exon  chr1         108925726
# 3                    ISM            mono-exon  chr1         108928073
# 7                    ISM            mono-exon  chr1         201896455
# ...                  ...                  ...   ...               ...
# 107424               ISM            mono-exon  chrX         107713223
# 107444               ISM            mono-exon  chrY           1398288
# 107455               NIC     intron retention  chrY           1285651
# 107487               ISM            mono-exon  chrY            992801
# 107490               ISM            mono-exon  chrY            319175
#
#         transcript_end category                    subcategory
# 0            108880418      NIC  mono-exon_by_intron_retention
# 1            108909981    Genic                      mono-exon
# 2            108926898    Genic                      mono-exon
# 3            108931970      NIC  mono-exon_by_intron_retention
# 7            201898889    Genic                      mono-exon
# ...                ...      ...                            ...
# 107424       107716269      NIC  mono-exon_by_intron_retention
# 107444         1399412      NIC  mono-exon_by_intron_retention
# 107455         1307499      ISM              internal_fragment
# 107487          994365    Genic                      mono-exon
# 107490          321317    Genic                      mono-exon
#
# [7665 rows x 9 columns]

# %% [markdown]
# # Monoexons

# %%
monoexon_mm = mismatches.loc[mismatches['subcategory'] == 'mono-exon']
monoexon_mm
# Out:
#                    gene_id                              isoform  \
# 1       ENSG00000121957.15   m54284U_210227_205004/61016242/ccs
# 2       ENSG00000121957.15   m54284U_210227_205004/84346647/ccs
# 7       ENSG00000163431.14   m54284U_200419_012632/53545803/ccs
# 34      ENSG00000116685.17  m54284U_210227_205004/122096460/ccs
# 39       ENSG00000251484.3  m54284U_200419_012632/112657704/ccs
# ...                    ...                                  ...
# 107148   ENSG00000236017.8   m54284U_210227_205004/64290982/ccs
# 107272   ENSG00000233661.1    m54284U_210227_205004/4589284/ccs
# 107360   ENSG00000268738.3   m54284U_200419_012632/93651732/ccs
# 107487   ENSG00000292335.1  m54284U_210227_205004/121636612/ccs
# 107490   ENSG00000292342.1  m54284U_200419_012632/106826569/ccs
#
#        isotools_category isotools_subcategory   chr  transcript_start  \
# 1                    ISM            mono-exon  chr1         108906669
# 2                    ISM            mono-exon  chr1         108925726
# 7                    ISM            mono-exon  chr1         201896455
# 34                   ISM            mono-exon  chr1          11919590
# 39                   ISM            mono-exon  chr1         109103706
# ...                  ...                  ...   ...               ...
# 107148               ISM            mono-exon  chrX           1412900
# 107272               ISM            mono-exon  chrX          63351095
# 107360               ISM            mono-exon  chrX         149592043
# 107487               ISM            mono-exon  chrY            992801
# 107490               ISM            mono-exon  chrY            319175
#
#         transcript_end category subcategory
# 1            108909981    Genic   mono-exon
# 2            108926898    Genic   mono-exon
# 7            201898889    Genic   mono-exon
# 34            11922106    Genic   mono-exon
# 39           109105540    Genic   mono-exon
# ...                ...      ...         ...
# 107148         1414741    Genic   mono-exon
# 107272        63356012    Genic   mono-exon
# 107360       149593938    Genic   mono-exon
# 107487          994365    Genic   mono-exon
# 107490          321317    Genic   mono-exon
#
# [3389 rows x 9 columns]

# %%
# First transcript from the list
isoseq['ENSG00000121957.15'].transcripts[13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # First transcript from the list
# ----> 2 isoseq['ENSG00000121957.15'].transcripts[13]
#
# IndexError: list index out of range
